# %%
import pandas as pd

# %% [markdown]
# Creating new features

# %%
df=pd.read_csv('retail_customer_segmentation.csv')

# %%
df=df.head(1500)

# %%
df

# %%
df.isnull().sum()

# %%
df.dropna(subset=['annual_income','avg_monthly_spend','purchase_frequency','discount_usage_rate','return_rate','browsing_time_minutes','support_interactions'],inplace=True)

# %%
df.isnull().sum()

# %%
df.shape

# %% [markdown]
# First Feature

# %%
df['total_spend']=df['avg_monthly_spend'] * df['months_active']

# %% [markdown]
# Second Feature

# %%
df['engagement_score']=df['browsing_time_minutes'] + df['purchase_frequency']+df['support_interactions']

# %%
df.columns

# %%
df=df[['customer_id', 'age', 'annual_income', 'months_active',
       'avg_monthly_spend', 'purchase_frequency', 'avg_order_value',
       'discount_usage_rate', 'return_rate', 'browsing_time_minutes',
       'support_interactions', 'payment_method', 'region', 'customer_segment',
       'total_spend', 'engagement_score','total_spend','engagement_score']]
