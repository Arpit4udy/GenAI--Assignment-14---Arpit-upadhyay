# %%
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')

# %%
numerical=['customer_id', 'age', 'annual_income', 'months_active',
       'avg_monthly_spend', 'purchase_frequency', 'avg_order_value',
       'discount_usage_rate', 'return_rate', 'browsing_time_minutes',
       'support_interactions','total_spend', 'engagement_score', 'total_spend.1',
       'engagement_score.1']
categorical=['payment_method', 'region', 'customer_segment']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
scaled=scaler.fit_transform(df[numerical])

# %%
scaled[:,2]
# Out:
# array([0.62863456, 0.33097147, 0.35399108, ..., 0.12434764, 0.40208801,
#        0.44273912], shape=(1021,))

# %% [markdown]
# the value clearly lies between 0 and 1.

# %% [markdown]
# ## Comparision

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()
minmax_scaler = MinMaxScaler()

standard_scaled = standard_scaler.fit_transform(df[numerical])
minmax_scaled = minmax_scaler.fit_transform(df[numerical])

# %%
comparison = pd.DataFrame(
    {
        'Original': df[numerical].iloc[:, 0].values,
        'StandardScaler': standard_scaled[:, 0],
        'MinMaxScaler': minmax_scaled[:, 0]
    }
)

print(comparison.head(10))
# Out:
#    Original  StandardScaler  MinMaxScaler
# 0     33554        0.559315      0.671894
# 1      9428       -1.120278      0.188717
# 2       200       -1.762709      0.003905
# 3     12448       -0.910033      0.249199
# 4     39490        0.972565      0.790775
# 5     42725        1.197777      0.855564
# 6     10823       -1.023162      0.216655
# 7      4145       -1.488068      0.082913
# 8     36959        0.796363      0.740087
# 9     43107        1.224371      0.863214
